# %% [raw]
# Notes :
# 1531,934069404_34543643308,110350144_67985219545_904677
# duplicates in start wiht the same time  but it does not affect the avg time spent because the result will be 0
#
# but for the error we drop them
#
# 1531	934069404_34543643308	110350144_67985219545_904677
# it reaches confirm but again goes to the start step and stays there, I interpreted it as error because all the ids were the same

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from functions import *
import scipy.stats as st
from scipy.stats import ttest_ind

# %matplotlib inline
import os

# %%
path = ('/Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/week5/Project/data/clean/df_web_clean.csv')
test = pd.read_csv(path)

# %%
test.drop(test.index[200:], inplace=True)

# %%
test
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 0             0        169  201385055_71273495308
# 1             1        169  201385055_71273495308
# 2             2        169  201385055_71273495308
# 3             3        169  201385055_71273495308
# 4             4        169  201385055_71273495308
# ..          ...        ...                    ...
# 195         195       1680   95496252_89175705853
# 196         196       1680   95496252_89175705853
# 197         197       1680   95496252_89175705853
# 198         198       1702  470573753_93844895765
# 199         199       1702  470573753_93844895765
#
#                          visit_id process_step            date_time
# 0    749567106_99161211863_557568       step_3  2017-04-12 20:22:05
# 1    749567106_99161211863_557568      confirm  2017-04-12 20:23:09
# 2    749567106_99161211863_557568       step_2  2017-04-12 20:20:31
# 3    749567106_99161211863_557568       step_1  2017-04-12 20:19:45
# ...

# %%
test['date_time']=pd.to_datetime(test['date_time'])
test = test.sort_values(['visit_id','date_time'])
test['end_of_the_step']= test.groupby('visit_id')['date_time'].shift(-1)

# %%
test.dtypes
# Out:
# Unnamed: 0                  int64
# client_id                   int64
# visitor_id                 object
# visit_id                   object
# process_step               object
# date_time          datetime64[ns]
# end_of_the_step    datetime64[ns]
# dtype: object

# %%
test2 = test.drop(test.index[50:])

# %%
test2['next_step']= test2.groupby(['visit_id','client_id','visitor_id'])['process_step'].shift(-1)

# %%
test2['next_step']= test2.groupby(['visit_id','client_id','visitor_id'])['process_step'].shift(-1)
steps = {
    'start': 1,
    'step_1': 2,
    'step_2': 3,
    'step_3': 4,
    'confirm': 5
}

test2['current_stp_nr'] = test2['process_step'].map(steps)
test2['next_stp_nr'] = test2['next_step'].map(steps)
test2['error'] = test2['next_stp_nr'] - test2['current_stp_nr']
Error = test2[test2['error'] <=0]
Error['sum_er'] = 1
Error.groupby(['process_step'])[['sum_er']].sum().rename(columns = {'sum_er':'total_errors'})

# %%
test2['error'] = test2['next_stp_nr'] - test2['current_stp_nr']

# %%
Error = test2[test2['error'] <=0]

# %%
Error
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 151         151       1531  934069404_34543643308
# 150         150       1531  934069404_34543643308
# 157         157       1531  934069404_34543643308
# 105         105       1346   123474046_4204671056
# 102         102       1346   123474046_4204671056
# 103         103       1346   123474046_4204671056
# 108         108       1346   123474046_4204671056
# 122         122       1399  395313004_27952045034
#
#                          visit_id process_step           date_time  \
# 151  110350144_67985219545_904677      confirm 2017-06-02 22:25:26
# 150  110350144_67985219545_904677        start 2017-06-02 22:32:08
# 157  110350144_67985219545_904677        start 2017-06-02 22:32:28
# 105   27144337_83739845380_214282       step_1 2017-06-06 18:20:36
# 102   27144337_83739845380_214282       step_3 2017-06-06 18:24:50
# 103   27144337_83739845380_214282        start 2017-06-06 18:26:15
# ...

# %%
Error['sum_er'] = 1
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_2767/2456516870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Error['sum_er'] = 1

# %%
df['is_error'] = (df['prev_step'] > df['process_step']).astype(int)

# %%
Error
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 151         151       1531  934069404_34543643308
# 150         150       1531  934069404_34543643308
# 157         157       1531  934069404_34543643308
# 105         105       1346   123474046_4204671056
# 102         102       1346   123474046_4204671056
# 103         103       1346   123474046_4204671056
# 108         108       1346   123474046_4204671056
# 122         122       1399  395313004_27952045034
#
#                          visit_id process_step           date_time  \
# 151  110350144_67985219545_904677      confirm 2017-06-02 22:25:26
# 150  110350144_67985219545_904677        start 2017-06-02 22:32:08
# 157  110350144_67985219545_904677        start 2017-06-02 22:32:28
# 105   27144337_83739845380_214282       step_1 2017-06-06 18:20:36
# 102   27144337_83739845380_214282       step_3 2017-06-06 18:24:50
# 103   27144337_83739845380_214282        start 2017-06-06 18:26:15
# ...

# %%
Error.groupby(['process_step'])[['sum_er']].sum().rename(columns = {'sum_er':'total_errors'})
# Out:
#               total_errors
# process_step
# confirm                  1
# start                    4
# step_1                   2
# step_3                   1

# %%
test2groupby(['visit_id','client_id','visitor_id'])['error'].apply(lambda x: x<=0
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 153         153       1531  934069404_34543643308
# 156         156       1531  934069404_34543643308
# 154         154       1531  934069404_34543643308
# 152         152       1531  934069404_34543643308
# 151         151       1531  934069404_34543643308
# 150         150       1531  934069404_34543643308
# 155         155       1531  934069404_34543643308
# 157         157       1531  934069404_34543643308
# 158         158       1531  934069404_34543643308
# 166         166       1621    45031672_9874942918
# 171         171       1621    45031672_9874942918
# 170         170       1621    45031672_9874942918
# 169         169       1621    45031672_9874942918
# 167         167       1621    45031672_9874942918
# 198         198       1702  470573753_93844895765
# 147         147       1516  182314299_63168583136
# 148         148       1516  182314299_63168583136
# 149         149       1516  182314299_63168583136
# ...

# %%
test ['time_diff'] = test.end_of_the_step - test.date_time

# %%
test
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 153         153       1531  934069404_34543643308
# 156         156       1531  934069404_34543643308
# 154         154       1531  934069404_34543643308
# 152         152       1531  934069404_34543643308
# 151         151       1531  934069404_34543643308
# ..          ...        ...                    ...
# 28           28        722  919259913_64837298108
# 26           26        722  919259913_64837298108
# 24           24        722  919259913_64837298108
# 23           23        722  919259913_64837298108
# 27           27        722  919259913_64837298108
#
#                          visit_id process_step           date_time  \
# 153  110350144_67985219545_904677        start 2017-06-02 22:22:44
# 156  110350144_67985219545_904677       step_1 2017-06-02 22:22:50
# 154  110350144_67985219545_904677       step_2 2017-06-02 22:23:01
# 152  110350144_67985219545_904677       step_3 2017-06-02 22:25:04
# ...

# %%
x = test[test['visit_id'] =='110350144_67985219545_904677']
x
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 153         153       1531  934069404_34543643308
# 156         156       1531  934069404_34543643308
# 154         154       1531  934069404_34543643308
# 152         152       1531  934069404_34543643308
# 151         151       1531  934069404_34543643308
# 150         150       1531  934069404_34543643308
# 155         155       1531  934069404_34543643308
# 157         157       1531  934069404_34543643308
# 158         158       1531  934069404_34543643308
#
#                          visit_id process_step           date_time  \
# 153  110350144_67985219545_904677        start 2017-06-02 22:22:44
# 156  110350144_67985219545_904677       step_1 2017-06-02 22:22:50
# 154  110350144_67985219545_904677       step_2 2017-06-02 22:23:01
# 152  110350144_67985219545_904677       step_3 2017-06-02 22:25:04
# 151  110350144_67985219545_904677      confirm 2017-06-02 22:25:26
# ...

# %%
test2 = test.drop(test.index[50:])

# %%
test2 # Assuming df is your DataFrame containing the data
test2.drop_duplicates(subset=['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time'], inplace=True)

# %%
test2
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 153         153       1531  934069404_34543643308
# 156         156       1531  934069404_34543643308
# 154         154       1531  934069404_34543643308
# 152         152       1531  934069404_34543643308
# 151         151       1531  934069404_34543643308
# 150         150       1531  934069404_34543643308
# 157         157       1531  934069404_34543643308
# 166         166       1621    45031672_9874942918
# 171         171       1621    45031672_9874942918
# 170         170       1621    45031672_9874942918
# 169         169       1621    45031672_9874942918
# 167         167       1621    45031672_9874942918
# 198         198       1702  470573753_93844895765
# 147         147       1516  182314299_63168583136
# 148         148       1516  182314299_63168583136
# 149         149       1516  182314299_63168583136
# 137         137       1516  182314299_63168583136
# 138         138       1516  182314299_63168583136
# ...

# %%
path3 = ('/Users/leilajavanmardi/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/week5/Project/data/clean/df_experiment_clean.csv')
df_clean = pd.read_csv(path3)
variation_df = df_clean[['client_id','variation']]
test2 = pd.merge(test2,variation_df, on= 'client_id')
test2 = test2[test2.variation != 'Unknown']

# %%
test2
# Out:
#     Unnamed: 0  client_id             visitor_id  \
# 0          198       1702  470573753_93844895765
# 1          147       1516  182314299_63168583136
# 2          148       1516  182314299_63168583136
# 3          149       1516  182314299_63168583136
# 4          137       1516  182314299_63168583136
# 5          138       1516  182314299_63168583136
# 6          106       1346   123474046_4204671056
# 7          105       1346   123474046_4204671056
# 8          104       1346   123474046_4204671056
# 9          109       1346   123474046_4204671056
# 10         107       1346   123474046_4204671056
# 11         102       1346   123474046_4204671056
# 12         103       1346   123474046_4204671056
# 13         108       1346   123474046_4204671056
# 14         110       1346   123474046_4204671056
# 15         111       1346   123474046_4204671056
# 16         177       1643  910842861_51062379179
# 17          79       1195  766842522_69992551638
# ...

# %%
tes_completion_rate = test2.copy()
grouped_confirm = tes_completion_rate.groupby('client_id')['process_step'].transform(lambda x: x == 'confirm')
values = np.where(grouped_confirm, 1, 0)

tes_completion_rate['completion_rate_success'] = values

tes_completion_rate
# Out:
#     Unnamed: 0  client_id             visitor_id  \
# 0          198       1702  470573753_93844895765
# 1          147       1516  182314299_63168583136
# 2          148       1516  182314299_63168583136
# 3          149       1516  182314299_63168583136
# 4          137       1516  182314299_63168583136
# 5          138       1516  182314299_63168583136
# 6          106       1346   123474046_4204671056
# 7          105       1346   123474046_4204671056
# 8          104       1346   123474046_4204671056
# 9          109       1346   123474046_4204671056
# 10         107       1346   123474046_4204671056
# 11         102       1346   123474046_4204671056
# 12         103       1346   123474046_4204671056
# 13         108       1346   123474046_4204671056
# 14         110       1346   123474046_4204671056
# 15         111       1346   123474046_4204671056
# 16         177       1643  910842861_51062379179
# 17          79       1195  766842522_69992551638
# ...

# %%
# calculation of Completion rate for the test group
tes_completion_rate = test2.copy()
#tes_completion_rate = tes_completion_rate[tes_completion_rate.process_step == 'confirm']
#tes_completion_rate['compltion_rate_sucess'] = 1
grouped_confirm = tes_completion_rate.groupby('client_id')['process_step'].transform(lambda x: x.eq('confirm').any())
values = np.where(grouped_confirm, 1, 0)

# Assign the calculated values to the new column
tes_completion_rate['completion_rate_success'] = values

# Define conditions and values
#conditions = (tes_completion_rate['process_step'] == 'confirm')
#values = np.where(conditions, 1, 0)

# Assign the calculated values to the new column
#tes_completion_rate['completion_rate_success'] = values

#tes_completion_rate.groupby('variation')['completion_rate_success'].value_counts()
tes_completion_rate
# Out:
#     Unnamed: 0  client_id             visitor_id  \
# 0          198       1702  470573753_93844895765
# 1          147       1516  182314299_63168583136
# 2          148       1516  182314299_63168583136
# 3          149       1516  182314299_63168583136
# 4          137       1516  182314299_63168583136
# 5          138       1516  182314299_63168583136
# 6          106       1346   123474046_4204671056
# 7          105       1346   123474046_4204671056
# 8          104       1346   123474046_4204671056
# 9          109       1346   123474046_4204671056
# 10         107       1346   123474046_4204671056
# 11         102       1346   123474046_4204671056
# 12         103       1346   123474046_4204671056
# 13         108       1346   123474046_4204671056
# 14         110       1346   123474046_4204671056
# 15         111       1346   123474046_4204671056
# 16         177       1643  910842861_51062379179
# 17          79       1195  766842522_69992551638
# ...

# %%
tes_completion = test2.copy()
tes_completion = tes_completion.groupby(['client_id', 'visitor_id', 'visit_id'])
tes_completion
tes_completion = pd.DataFrame(tes_completion)
tes_completion
# Out:
#                                                    0  \
# 0  (647, 66758770_53988066587, 40369564_401016828...
# 1  (1195, 766842522_69992551638, 393817425_390152...
# 2  (1346, 123474046_4204671056, 27144337_83739845...
# 3  (1516, 182314299_63168583136, 255400977_380395...
# 4  (1643, 910842861_51062379179, 379946188_177302...
# 5  (1702, 470573753_93844895765, 243444359_786960...
#
#                                                    1
# 0      Unnamed: 0  client_id            visitor_i...
# 1      Unnamed: 0  client_id             visitor_...
# 2      Unnamed: 0  client_id            visitor_i...
# 3     Unnamed: 0  client_id             visitor_i...
# 4      Unnamed: 0  client_id             visitor_...
# 5     Unnamed: 0  client_id             visitor_i...

# %%
test2
# Out:
#     Unnamed: 0  client_id             visitor_id  \
# 0          198       1702  470573753_93844895765
# 1          147       1516  182314299_63168583136
# 2          148       1516  182314299_63168583136
# 3          149       1516  182314299_63168583136
# 4          137       1516  182314299_63168583136
# 5          138       1516  182314299_63168583136
# 6          106       1346   123474046_4204671056
# 7          105       1346   123474046_4204671056
# 8          104       1346   123474046_4204671056
# 9          109       1346   123474046_4204671056
# 10         107       1346   123474046_4204671056
# 11         102       1346   123474046_4204671056
# 12         103       1346   123474046_4204671056
# 13         108       1346   123474046_4204671056
# 14         110       1346   123474046_4204671056
# 15         111       1346   123474046_4204671056
# 16         177       1643  910842861_51062379179
# 17          79       1195  766842522_69992551638
# ...

# %%
# calculation of Completion rate for the test group
tes_complition_rate = test2.copy()
tes_complition_rate2 = tes_complition_rate[tes_complition_rate.process_step == 'confirm']
tes_complition_rate2['compltion_rate_sucess'] = 1

tes_complition_rate2.groupby('variation')[['compltion_rate_sucess']].count()
#completion_rate_test = round((num_user_confirm_test / total_users_test)*100,2)

#print(f'The number of users in test group who reached the confirm step is {num_user_confirm_test} and the number of total test sample is {total_users_test}')
#print (f'The completion rate in test group is {completion_rate_test}')
#tes_complition_rate[tes_complition_rate.process_step == 'confirm'].groupby('client_id')
#tes_complition_rate2
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_2767/2411988239.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tes_complition_rate2['compltion_rate_sucess'] = 1
#            compltion_rate_sucess
# variation
# Control                        1
# Test                           3

# %%
test2[test2.visit_id == '110350144_67985219545_904677']
# Out:
#      Unnamed: 0  client_id             visitor_id  \
# 153         153       1531  934069404_34543643308
# 156         156       1531  934069404_34543643308
# 154         154       1531  934069404_34543643308
# 152         152       1531  934069404_34543643308
# 151         151       1531  934069404_34543643308
# 150         150       1531  934069404_34543643308
# 155         155       1531  934069404_34543643308
# 157         157       1531  934069404_34543643308
# 158         158       1531  934069404_34543643308
#
#                          visit_id process_step           date_time  \
# 153  110350144_67985219545_904677        start 2017-06-02 22:22:44
# 156  110350144_67985219545_904677       step_1 2017-06-02 22:22:50
# 154  110350144_67985219545_904677       step_2 2017-06-02 22:23:01
# 152  110350144_67985219545_904677       step_3 2017-06-02 22:25:04
# 151  110350144_67985219545_904677      confirm 2017-06-02 22:25:26
# ...

# %%
# Assuming test2 is your DataFrame
test ['time_diff'] = test.end_of_the_step - test.date_time
result = test2.groupby(['visit_id', 'process_step'])[['time_diff']].mean().rename(columns={'time_diff': 'average'}).reset_index()

# Now 'average' column will contain the mean values
result
# Out:
#                         visit_id process_step                average
# 0   110350144_67985219545_904677      confirm        0 days 00:06:42
# 1   110350144_67985219545_904677        start 0 days 00:00:06.500000
# 2   110350144_67985219545_904677       step_1        0 days 00:00:11
# 3   110350144_67985219545_904677       step_2        0 days 00:02:03
# 4   110350144_67985219545_904677       step_3        0 days 00:00:22
# 5   178305257_74757299896_508747      confirm                    NaT
# 6   178305257_74757299896_508747        start        0 days 00:02:23
# 7   178305257_74757299896_508747       step_1        0 days 00:00:32
# 8   178305257_74757299896_508747       step_2        0 days 00:02:31
# 9   178305257_74757299896_508747       step_3        0 days 00:01:15
# 10  243444359_78696078676_118990      confirm                    NaT
# 11  255400977_38039535960_779641      confirm                    NaT
# 12  255400977_38039535960_779641        start        0 days 00:00:56
# ...

# %% [markdown]
# client_id 1531,visitor_id 934069404_34543643308,visit_id 110350144_67985219545_904677

# %%
result= result.groupby('process_step')[['average']].mean()

# %%
result
# Out:
#                                average
# process_step
# confirm                0 days 00:06:42
# start           0 days 00:00:35.850000
# step_1          0 days 00:00:46.437500
# step_2                 0 days 00:02:51
# step_3       0 days 00:01:43.285714285

# %%
test.process_step.unique()
# Out:
# array(['start', 'step_1', 'step_2', 'step_3', 'confirm'], dtype=object)

# %%
steps = {
    'start': 1,
    'step_1': 2,
    'step_2': 3,
    'step_3': 4,
    'confirm': 5
}

test['current_st_nr'] = test.groupby(['client_id','visit_id'])['process_step'].map(steps)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[240], line 9
#       1 steps = {
#       2     'start': 1,
#       3     'step_1': 2,
#    (...)
#       6     'confirm': 5
#       7 }
# ----> 9 test['current_st_nr'] = test.groupby(['client_id','visit_id'])['process_step'].map(steps)
#
# File ~/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/week5/Project/env2/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'map'

# %%
steps = {
    'start': 1,
    'step_1': 2,
    'step_2': 3,
    'step_3': 4,
    'confirm': 5
}

# %%
# Assuming steps is a dictionary that maps process_step values to new values
test['current_st_nr'] = test.groupby(['client_id', 'visit_id'])['process_step'].transform(steps)

# If steps is a function, you can use apply instead
# test['current_st_nr'] = test.groupby(['client_id', 'visit_id'])['process_step'].apply(steps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[243], line 2
#       1 # Assuming steps is a dictionary that maps process_step values to new values
# ----> 2 test['current_st_nr'] = test.groupby(['client_id', 'visit_id'])['process_step'].transform(steps)
#       4 # If steps is a function, you can use apply instead
#       5 # test['current_st_nr'] = test.groupby(['client_id', 'visit_id'])['process_step'].apply(steps)
#
# File ~/Desktop/Leila/Coding_IronHack/Data_Analytics_Bootcamp/week5/Project/env2/lib/python3.11/site-packages/pandas/core/groupby/generic.py:517, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     514 @Substitution(klass="Series", example=__examples_series_doc)
#     515 @Appender(_transform_template)
#     516 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# ...

# %%
#test['next_st_nr'] = test.next_step.map(steps)
test

# %%
first_steps = {
    'start': 1,
    'step_1': 2,
    'step_2': 3,
    'step_3': 4,
    'confirm': 5
}

next_steps = {
    'start': -1,
    'step_1': -2,
    'step_2': -3,
    'step_3': -4,
    'confirm': -5
}
test['current_st_nr'] = test.process_step.map(first_steps)
test['next_st_nr'] = test.next_step.map(next_steps)

# %%
test

# %%
test

# %%
# error 
test.groupby(['client_id','visitor_id','visit_id'])[['next_st_nr','current_st_nr']]

# %%
test

# %%
test['error'] = test['next_st_nr']- test['current_st_nr']
test
